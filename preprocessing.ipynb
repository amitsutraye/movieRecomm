# %%
import pandas as pd
import numpy as np
import ast

pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)

# %%
df_load = pd.read_csv('data/dff_all_movies.csv')

# %%
df = df_load.copy()

# %%
df.head(2)
# Out:
#    imdb_popularity  tmdb_vote_average  tmdb_vote_count  tmdb_revenue  \
# 0           19.944              5.784             2436       4257354
# 1           13.970              6.533              302      12136938
#
#    tmdb_runtime  tmdb_budget tmdb_original_title  \
# 0            98      4000000          Four Rooms
# 1           109     21000000      Judgment Night
#
#                                        tmdb_overview  tmdb_popularity  \
# 0  It's Ted the Bellhop's first night on the job....           15.295
# 1  While racing to a boxing match, Frank, Mike, J...           13.564
#
#                                         tmdb_tagline  \
# 0  Twelve outrageous guests. Four scandalous requ...
# 1     Don't move. Don't whisper. Don't even breathe.
#
#   tmdb_production_companies  \
# 0     Miramax, A Band Apart
# 1  Largo Entertainment, JVC
#
#                                            tmdb_cast  \
# 0  Kimberly Blair, Sammi Davis, Paul Skemp, Bruce...
# ...

# %%
df['imdb_popularity'].describe()
# Out:
# count    38160.000000
# mean         8.639404
# std         20.516256
# min          0.000000
# 25%          2.067000
# 50%          4.253000
# 75%          8.762000
# max        564.206000
# Name: imdb_popularity, dtype: float64

# %%
df['tomatoes_audienceScore'].describe()
# Out:
# count    38160.000000
# mean        52.859215
# std         20.808757
# min          0.000000
# 25%         41.000000
# 50%         52.859215
# 75%         67.000000
# max        100.000000
# Name: tomatoes_audienceScore, dtype: float64

# %%
df_main = df[['tmdb_original_title','tmdb_overview','tmdb_tagline','lboxd_tagline','lboxd_description','lboxd_theme','genres','keywords','mood','poster_path']]
df_main.head(2)
# Out:
#   tmdb_original_title                                      tmdb_overview  \
# 0          Four Rooms  It's Ted the Bellhop's first night on the job....
# 1      Judgment Night  While racing to a boxing match, Frank, Mike, J...
#
#                                         tmdb_tagline  \
# 0  Twelve outrageous guests. Four scandalous requ...
# 1     Don't move. Don't whisper. Don't even breathe.
#
#                                        lboxd_tagline  \
# 0  Twelve outrageous guests. Four scandalous requ...
# 1     Don't move. Don't whisper. Don't even breathe.
#
#                                    lboxd_description  \
# 0  It's Ted the Bellhop's first night on the job....
# 1  While racing to a boxing match, Frank, Mike, J...
#
#                                          lboxd_theme  \
# 0  ['Crude humor and satire', 'Relationship comed...
# 1  ['Adrenaline-fueled action and fast cars', 'Ex...
#
#                                               genres  \
# ...

# %%
['dramatic' 'tense' 'exciting']
df['mood'] = df['mood'].apply(lambda x: ast.literal_eval(x.replace(" ",","))[0])
df['mood']
# Out:
# 0          dramatic
# 1             tense
# 2          dramatic
# 3        melancholy
# 4          dramatic
#             ...
# 38155      dramatic
# 38156         tense
# 38157      dramatic
# 38158      dramatic
# 38159         tense
# Name: mood, Length: 38160, dtype: object

# %%
df.head(2)
# Out:
#    imdb_popularity  tmdb_vote_average  tmdb_vote_count  tmdb_revenue  \
# 0           19.944              5.784             2436       4257354
# 1           13.970              6.533              302      12136938
#
#    tmdb_runtime  tmdb_budget tmdb_original_title  \
# 0            98      4000000          Four Rooms
# 1           109     21000000      Judgment Night
#
#                                        tmdb_overview  tmdb_popularity  \
# 0  It's Ted the Bellhop's first night on the job....           15.295
# 1  While racing to a boxing match, Frank, Mike, J...           13.564
#
#                                         tmdb_tagline  \
# 0  Twelve outrageous guests. Four scandalous requ...
# 1     Don't move. Don't whisper. Don't even breathe.
#
#   tmdb_production_companies  \
# 0     Miramax, A Band Apart
# 1  Largo Entertainment, JVC
#
#                                            tmdb_cast  \
# 0  Kimberly Blair, Sammi Davis, Paul Skemp, Bruce...
# ...

# %%
df['popularity_growth'].describe()
# Out:
# count    3.815400e+04
# mean              inf
# std               NaN
# min      0.000000e+00
# 25%      6.000000e-02
# 50%      1.393063e-01
# 75%      4.132804e-01
# max               inf
# Name: popularity_growth, dtype: float64

# %%
cols_to_drop = ['imdb_popularity','tmdb_revenue','tmdb_runtime','tmdb_budget','tmdb_popularity','tmdb_credits','mubi_movie_popularity','mubi_critic_comments','POSITIVE_count','NEGATIVE_count','imdb_release_year','popularity_growth','rating_dispersion','popularity_per_budget']

df.drop(columns=cols_to_drop,inplace=True)

# %%
df['tmdb_rating_count'] = (df['tmdb_vote_average']*df['tmdb_vote_count'])
df['imdb_score_log'] = np.log1p(df['tmdb_rating_count'])
df['sentiment_ratio_log'] = np.log1p(df['sentiment_ratio']) 
df.drop(columns=['tmdb_vote_average','tmdb_vote_count','tmdb_rating_count','sentiment_ratio'],inplace=True)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

columns_to_normalize = ['tomatoes_audienceScore', 'tomatoes_tomatoMeter', 'lboxd_rating','mubi_rating_score','sentiment_ratio_log','years_since_release','imdb_score_log']
df[columns_to_normalize] = scaler.fit_transform(df[columns_to_normalize])

# %%
df.head(2)
# Out:
#   tmdb_original_title                                      tmdb_overview  \
# 0          Four Rooms  It's Ted the Bellhop's first night on the job....
# 1      Judgment Night  While racing to a boxing match, Frank, Mike, J...
#
#                                         tmdb_tagline  \
# 0  Twelve outrageous guests. Four scandalous requ...
# 1     Don't move. Don't whisper. Don't even breathe.
#
#   tmdb_production_companies  \
# 0     Miramax, A Band Apart
# 1  Largo Entertainment, JVC
#
#                                            tmdb_cast  \
# 0  Kimberly Blair, Sammi Davis, Paul Skemp, Bruce...
# 1  Doug Wert, Darin Mangan, Stephen Dorff, Nigel ...
#
#                                        tmdb_director  \
# 0  Alexandre Rockwell, Quentin Tarantino, Allison...
# 1                                    Stephen Hopkins
#
#                         tmdb_director_of_photography  \
# 0  Andrzej Sekula, Rodrigo García, Guillermo Nava...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38160 entries, 0 to 38159
# Data columns (total 25 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   tmdb_original_title           38160 non-null  object
#  1   tmdb_overview                 38160 non-null  object
#  2   tmdb_tagline                  38160 non-null  object
#  3   tmdb_production_companies     38160 non-null  object
#  4   tmdb_cast                     38160 non-null  object
#  5   tmdb_director                 38160 non-null  object
#  6   tmdb_director_of_photography  38160 non-null  object
#  7   tmdb_writers                  38160 non-null  object
#  8   tmdb_producers                38160 non-null  object
#  9   tmdb_music_composer           38160 non-null  object
#  10  tomatoes_audienceScore        38160 non-null  float64
#  11  tomatoes_tomatoMeter          38160 non-null  float64
# ...

# %%
df.to_csv('data\df_movies.csv', index=False)

# %%
df.shape
# Out:
# (38160, 25)

# %% [markdown]
# ## Similarity Matrix

# %%
dff = pd.read_csv('data\df_movies.csv')

# %%
dff.head(2)
# Out:
#   tmdb_original_title                                      tmdb_overview  \
# 0          Four Rooms  It's Ted the Bellhop's first night on the job....
# 1      Judgment Night  While racing to a boxing match, Frank, Mike, J...
#
#                                         tmdb_tagline  \
# 0  Twelve outrageous guests. Four scandalous requ...
# 1     Don't move. Don't whisper. Don't even breathe.
#
#   tmdb_production_companies  \
# 0     Miramax, A Band Apart
# 1  Largo Entertainment, JVC
#
#                                            tmdb_cast  \
# 0  Kimberly Blair, Sammi Davis, Paul Skemp, Bruce...
# 1  Doug Wert, Darin Mangan, Stephen Dorff, Nigel ...
#
#                                        tmdb_director  \
# 0  Alexandre Rockwell, Quentin Tarantino, Allison...
# 1                                    Stephen Hopkins
#
#                         tmdb_director_of_photography  \
# 0  Andrzej Sekula, Rodrigo García, Guillermo Nava...
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer
# Out:
# (38160, 25)

# %%
df['years_since_release'].dtype
# Out:
# dtype('float64')

# %%
text_columns = ['tmdb_overview', 'tmdb_tagline', 'tmdb_production_companies', 'tmdb_cast', 'tmdb_director','tmdb_director_of_photography', 'tmdb_writers', 'tmdb_producers', 'tmdb_music_composer', 'lboxd_tagline','lboxd_description','lboxd_theme','genres','keywords','primary_language','mood']  # Example text columns
numerical_columns = ['tomatoes_audienceScore', 'tomatoes_tomatoMeter','lboxd_rating','mubi_rating_score','years_since_release','imdb_score_log','sentiment_ratio_log']  # Example numerical columns
model_path = 'models/all-MiniLM-L6-v2' 
model = SentenceTransformer(model_path)

# %%
def combine_features(row, text_cols, numerical_cols):
   
    # Combine only text features that are present in the DataFrame
    text_features = ' '.join([str(row[col]) for col in text_cols if col in row])
    
    # Combine numerical features into a single string
    numerical_features = ' '.join([str(row[col]) for col in numerical_cols if col in row])
    
    return f"{text_features}"

# Combine features for each row
df['combined_features_only_text'] = df.apply(combine_features, axis=1, args=(text_columns, numerical_columns))
combined_features = df['combined_features_only_text'].tolist()
embeddings = model.encode(combined_features, convert_to_numpy=True)
similarity_matrix = cosine_similarity(embeddings)

# %%
def combine_features(row, text_cols, numerical_cols):
   
    # Combine only text features that are present in the DataFrame
    text_features = ' '.join([str(row[col]) for col in text_cols if col in row])
    
    # Combine numerical features into a single string
    numerical_features = ' '.join([str(row[col]) for col in numerical_cols if col in row])
    
    return f"{text_features} {numerical_features}"

# %%
# Combine features for each row
df['combined_features'] = df.apply(combine_features, axis=1, args=(text_columns, numerical_columns))

# %%
combined_features = df['combined_features'].tolist()

# %%
embeddings = model.encode(combined_features, convert_to_numpy=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 embeddings = model.encode(combined_features, convert_to_numpy=True)
#
# File c:\Users\Toshiba\AppData\Local\Programs\Python\Python311\Lib\site-packages\sentence_transformers\SentenceTransformer.py:601, in SentenceTransformer.encode(self, sentences, prompt_name, prompt, batch_size, show_progress_bar, output_value, precision, convert_to_numpy, convert_to_tensor, device, normalize_embeddings, **kwargs)
#     598 features.update(extra_features)
#     600 with torch.no_grad():
# --> 601     out_features = self.forward(features, **kwargs)
#     602     if self.device.type == "hpu":
#     603         out_features = copy.deepcopy(out_features)
#
# ...

# %%
from sklearn.metrics.pairwise import cosine_similarity



def combine_features(row, text_cols, numerical_cols):
   
    # Combine only text features that are present in the DataFrame
    text_features = ' '.join([str(row[col]) for col in text_cols if col in row])
    
    # Combine numerical features into a single string
    numerical_features = ' '.join([str(row[col]) for col in numerical_cols if col in row])
    
    return f"{text_features} {numerical_features}"

def compute_embeddings(model, df, text_cols, numerical_cols):
 
    # Combine features for each row
    df['combined_features'] = df.apply(combine_features, axis=1, args=(text_cols, numerical_cols))
    combined_features = df['combined_features'].tolist()
    
    # Compute embeddings using the model
    embeddings = model.encode(combined_features, convert_to_numpy=True)
    return embeddings

def compute_similarity_matrix(embeddings):
    
    similarity_matrix = cosine_similarity(embeddings)
    return similarity_matrix

def create_similarity_matrix(df, text_cols, numerical_cols, model):
  
    # Filter text and numerical columns to include only those present in the DataFrame
    text_cols = [col for col in text_cols if col in df.columns]
    numerical_cols = [col for col in numerical_cols if col in df.columns]
    
    # Normalize numerical columns
    df = preprocess_numerical_columns(df, numerical_cols)
    
    # Compute embeddings
    embeddings = compute_embeddings(model, df, text_cols, numerical_cols)
    
    # Create the similarity matrix
    similarity_matrix = compute_similarity_matrix(embeddings)
    return similarity_matrix

# Example usage
similarity_matrix = create_similarity_matrix(df, text_columns, numerical_columns, model)
# Out:
# C:\Users\Toshiba\AppData\Local\Temp\ipykernel_828\2116582851.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['combined_features'] = df.apply(combine_features, axis=1, args=(text_cols, numerical_cols))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[60], line 100
#      97     return similarity_matrix
#      99 # Example usage
# --> 100 similarity_matrix = create_similarity_matrix(df, text_columns, numerical_columns, model)
#
# Cell In[60], line 93, in create_similarity_matrix(df, text_cols, numerical_cols, model)
#      90 df = preprocess_numerical_columns(df, numerical_cols)
#      92 # Compute embeddings
# ...
